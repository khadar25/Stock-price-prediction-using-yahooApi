# %% [markdown]
# # Stock-Price-Prediction using LSTM, ARIMA and Seasonal ARIMA with yahoo_financeApi
# ## Autoregressive Integrated Moving Averages
# The general process for ARIMA models is the following:
#
# * Visualize the Time Series Data
# * Make the time series data stationary
# * Plot the Correlation and AutoCorrelation Charts
# * Construct the ARIMA Model or Seasonal ARIMA based on the data
# * Use the model to make predictions
# <br>
# Let's go through these steps!

# %%
# !pip install yahoo_finance_api2
# Out:
# ...
#   Created wheel for yahoo-finance-api2: filename=yahoo_finance_api2-0.0.8-cp36-none-any.whl size=3695 sha256=8a9269c7542c13856d0f15b867ed9a4af371800b7de47bc5313915c7390d98c7
#   Stored in directory: /root/.cache/pip/wheels/af/fc/9e/54be65b5ff75f526b464837f8a6b0ee521e545c59b219bd862
# ...
#   Created wheel for pprint: filename=pprint-0.1-cp36-none-any.whl size=1251 sha256=107a63fa6b21366ddf84e35f2605a06b85f9417a605541412aeffd85f3ee3632
#   Stored in directory: /root/.cache/pip/wheels/42/d4/c6/16a6495aecc1bda5d5857bd036efd50617789ba9bea4a05124
# Successfully built yahoo-finance-api2 pprint
# ...

# %% [markdown]
# ## Data Collection

# %%
# Install yahoo Finance for download the Finance market data 
# !pip install yfinance
# Out:
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.54-py2.py3-none-any.whl size=22409 sha256=407bb0bf215fe1fbc748bca1fbaccf00b39fe8d861b103b7e725ee5317477d56
#   Stored in directory: /root/.cache/pip/wheels/f9/e3/5b/ec24dd2984b12d61e0abf26289746c2436a0e7844f26f2515c
# Successfully built yfinance
# ...

# %%
import yfinance as yf
import datetime

stocks = ["INFY.NS"]

# %%
# Import the api of yahoo finance to fetch the data of the diffrent stocks
import yfinance as yf
import datetime
from google.colab import files


# Printing diffrent organisation names 
print("1.'Tech Mahindra Ltd.(L)'")
print("2.'Infosys Ltd.(L)'")
print("3.'HCL Technologies Ltd.(L)'")
print("4.'Wipro Ltd. (L)'")
print("5.'Larsen & Toubro Infotech Ltd.(L)'")
print("6.'Tata Consultancy Services Ltd.(L)'")
print("7.'Mindtree Ltd. (L)'")
print("8.'KPIT Technologies Ltd. (L)'")
print("9.'Oracle Financial Services Software Ltd. (L)'")
print("10.'Mphasis Ltd (L)'")

# Selecting the listing name of the organisation
choice = int(input('Enter your choice'))

# Importing the datetime packages
from datetime import datetime
from dateutil.parser import parse
import pandas as pd

class month_excp(Exception):
      pass
class year_format(Exception):
      pass
class year_range(Exception):
      pass
class day_of_month(Exception):
      pass
    
# Converting the string into datetime format
try:
    strt= input("Enter the starting date in format 'yyyy-mm-dd'")
    chk_strt_date=strt.split('-')
    #print(chk_strt_date)
    if(len(chk_strt_date[0])!=4):
          raise year_format
    if(int(chk_strt_date[0])<2010 or int(chk_strt_date[0])>datetime.now().year):
          raise year_range
    if(int(chk_strt_date[1]) > 12):
          raise month_excp
    days_in_month = {1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}
    if( 0 < int(chk_strt_date[2]) <= (days_in_month[int(chk_strt_date[1])])):
          pass
    else:
          if(int(chk_strt_date[1])%4==0):
            days_in_month={1:31, 2:29, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}
            if( 0 < int(chk_strt_date[2]) <= (days_in_month[int(chk_strt_date[1])])):
                  pass
            else:
                  raise day_of_month

    start = datetime.strptime(strt, '%Y-%m-%d')
    last = input("Enter the ending date in format 'yyyy-mm-dd'")
    chk_strt_date=strt.split('-')
    #print(chk_strt_date)
    if(len(chk_strt_date[0])!=4):
          raise year_format
    if(int(chk_strt_date[0])<2010 or int(chk_strt_date[0])>datetime.now().year):
          raise year_range
    if(int(chk_strt_date[1]) > 12):
          raise month_excp
    days_in_month = {1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}
    if( 0 < int(chk_strt_date[2]) <= (days_in_month[int(chk_strt_date[1])])):
          pass
    else:
          if(int(chk_strt_date[1])%4==0):
            days_in_month={1:31, 2:29, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}
            if( 0 < int(chk_strt_date[2]) <= (days_in_month[int(chk_strt_date[1])])):
                  pass
            else:
                  raise day_of_month
      
    end = datetime.strptime(last, '%Y-%m-%d')
except year_format:
    print('The Year you have entered is not valid')
except year_range:
    print("The year should be in between '2010' and "+str(datetime.now().year))
except month_excp:
    print('The month you have entered is not valid')
except day_of_month:
    print("The date you have entered is incorrect")

    
if(choice == 1):
    stck='TECHM.NS'
    df = yf.download(stck, start=start, end=end)
    df.to_csv('stck.csv')
    files.download('stck.csv')
if(choice == 2):  
    stck='INFY.NS'
    df = yf.download(stck, start=start, end=end)
    df.to_csv('stck.csv')
    files.download('stck.csv')

if(choice == 3):
    stck='HCLTECH.NS'
    df = yf.download(stck, start=start, end=end)
    df.to_csv('stck.csv')
    files.download('stck.csv')

if(choice == 4):
    stck='WIPRO.NS'
    df = yf.download(stck, start=start, end=end)
    df.to_csv('stck.csv')
    files.download('stck.csv')

if(choice == 5):
    stck='LTI.NS'
    df = yf.download(stck, start=start, end=end)
    df.to_csv('stck.csv')
    files.download('stck.csv')

if(choice == 6):
    stck='TCS.NS'
    df = yf.download(stck, start=start, end=end)
    df.to_csv('stck.csv')
    files.download('stck.csv')

if(choice == 7):
    stck='MINDTREE.NS'
    df = yf.download(stck, start=start, end=end)
    df.to_csv('stck.csv')
    files.download('stck.csv')

if(choice == 8):
    stck='KPITTECH.NS'
    df = yf.download(stck, start=start, end=end)
    df.to_csv('stck.csv')
    files.download('stck.csv')

if(choice == 9):
    stck='OFSS.NS'
    df = yf.download(stck, start=start, end=end)
    df.to_csv('stck.csv')
    files.download('stck.csv')

if(choice == 10):
    stck='MPHASIS.NS'
    df = yf.download(stck, start=start, end=end)
    df.to_csv('stck.csv')
    files.download('stck.csv')

#to download the data to the local system  
stocks = [stck]
# Out:
# 1.'Tech Mahindra Ltd.(L)'
# 2.'Infosys Ltd.(L)'
# 3.'HCL Technologies Ltd.(L)'
# 4.'Wipro Ltd. (L)'
# 5.'Larsen & Toubro Infotech Ltd.(L)'
# 6.'Tata Consultancy Services Ltd.(L)'
# 7.'Mindtree Ltd. (L)'
# 8.'KPIT Technologies Ltd. (L)'
# 9.'Oracle Financial Services Software Ltd. (L)'
# 10.'Mphasis Ltd (L)'
# Enter your choice2
# Enter the starting date in format 'yyyy-mm-dd'2010-01-11
# Enter the ending date in format 'yyyy-mm-dd'2020-01-11
# [*********************100%***********************]  1 of 1 completed

# %%
# Ploting the actual data
from matplotlib import pyplot
pyplot.figure(figsize=(50,8))
pyplot.plot(df)

# %% [markdown]
# ### Testing For Stationarity

# %%
df.head()
# Out:
#                   Open        High  ...   Adj Close    Volume
# Date                                ...
# 2010-01-11  309.388000  313.087006  ...  125.764114   7849656
# 2010-01-12  312.500000  324.250000  ...  130.679413  24859680
# 2010-01-13  309.605988  336.875000  ...  135.556747  19704040
# 2010-01-14  334.875000  337.862000  ...  135.872314   8413904
# 2010-01-15  336.218994  336.562012  ...  135.167526   5049504
#
# [5 rows x 6 columns]

# %%
from statsmodels.tsa.stattools import adfuller
#Ho: It is non stationary
#H1: It is stationary

def adfuller_test(close):
    result=adfuller(close)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
adfuller_test(df['Close'])
# Out:
# ADF Test Statistic : -0.7690655651597306
# p-value : 0.8280403981655378
# #Lags Used : 8
# Number of Observations Used : 2455
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %%
test_result=adfuller(df['Close'])

# %%
test_result
# Out:
# (-0.7690655651597306,
#  0.8280403981655378,
#  8,
#  2455,
#  {'1%': -3.433016456478213,
#   '10%': -2.567397105578623,
#   '5%': -2.8627180168175133},
#  17191.264521789617)

# %% [markdown]
# ## Auto Regressive Model

# %%
from pandas.plotting import autocorrelation_plot
import matplotlib.pyplot as plt
autocorrelation_plot(df['Close'][:100])
plt.show()

# %% [markdown]
# ## Autocorrelation and Partial Autocorrelation
# > Identification of an AR model is often best done with the PACF.
# * For an AR model, the theoretical PACF “shuts off” past the order of the model.
# * The phrase “shuts off” means that in theory the partial autocorrelations are equal to 0 beyond that point. Put another way, the number of non-zero partial autocorrelations gives the order of the AR model.
# * By the “order of the model” we mean the most extreme lag of x that is used as a predictor.
#
# > Identification of an MA model is often best done with the ACF rather than the PACF.
# * For an MA model, the theoretical PACF does not shut off, but instead tapers toward 0 in some manner.
# * A clearer pattern for an MA model is in the ACF. The ACF will have non-zero autocorrelations only at lags involved in the model.
#
# p,d,q p AR model lags d differencing q MA lags

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = plot_acf(df['Close'].iloc[13:],lags=40,ax=ax1)
ax2 = fig.add_subplot(212)
fig = plot_pacf(df['Close'].iloc[13:],lags=40,ax=ax2)

# %% [markdown]
# ALGORITHM

# %% [markdown]
# LSTM

# %%
len(train)/30
# Out:
# 65.7

# %%
# Importing required libraries
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
import pandas as pd
import numpy as np

# Creating dataframe
data = df
new_data = pd.DataFrame(index=range(0,len(df)),columns=['Date', 'Close'])
for i in range(0,len(data)):
    new_data['Date'][i] = data.index[i]
    new_data['Close'][i] = data['Close'][i]

# Setting index
new_data.index = new_data.Date
new_data.drop('Date', axis=1, inplace=True)

# Creating train and test sets
dataset = new_data.values
train = dataset[0: int(len(dataset) * .80)]
valid = dataset[int(len(dataset) * .80):]

# Feature Scaling
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

# Creating a data structure with 60 timesteps and 1 output
x_train, y_train = [], []
for i in range(60,len(train)): # range can also be taken as range(len(train)/30, len(train))
    x_train.append(scaled_data[i-60:i,0])
    y_train.append(scaled_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)

# Reshaping
x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))

# Create and fit the LSTM network
model = Sequential()

# Adding the first LSTM layer with some Dropout regularisation
model.add(LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(LSTM(units=50))
model.add(Dense(1))

# Compiling the LSTM
model.compile(loss='mean_squared_error', optimizer='adam')

# Fitting the LSTM to the training set
model.fit(x_train, y_train, epochs=5, batch_size=1, verbose=2)

# Making the predictions and visualising the results
inputs = new_data[len(new_data) - len(valid) - 60:].values
inputs = inputs.reshape(-1,1)
inputs  = scaler.transform(inputs)
X_test = []

for i in range(60,inputs.shape[0]):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)

X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
closing_price = model.predict(X_test)
closing_price = scaler.inverse_transform(closing_price)

# Finding the rms value
rms=np.sqrt(np.mean(np.power((valid-closing_price),2)))
print('RMSE LSTM ::'+str(rms))

# For plotting the graph
import matplotlib.pyplot as plt
plt.figure(figsize=(50,8))
train = new_data[0:int(len(dataset) * .80)]
valid = new_data[int(len(dataset) * .80):]
valid['Predictions'] = closing_price
plt.plot(train['Close'],label='training data')
plt.plot(valid[['Close','Predictions']],label='testing data')

plt.legend()
# Out:
# Epoch 1/5
#  - 71s - loss: 0.0012
# Epoch 2/5
#  - 68s - loss: 4.7747e-04
# Epoch 3/5
#  - 69s - loss: 3.4234e-04
# Epoch 4/5
#  - 69s - loss: 2.8982e-04
# Epoch 5/5
#  - 70s - loss: 2.6057e-04
# RMSE LSTM ::17.531610449851385
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print('RMSE LSTM ::'+str(rms))
# Out:
# RMSE LSTM ::17.531610449851385

# %%
# Accuracy
print('accuracy  ::' + str(100-rms))
# Out:
# accuracy  ::82.46838955014861

# %% [markdown]
# ARIMA

# %%
# Importing required libraries
from pandas import datetime
from pandas import DataFrame
from statsmodels.tsa.arima_model import ARIMA
from matplotlib import pyplot
from sklearn.metrics import mean_squared_error

# Fit the model
model = ARIMA(df['Close'], order=(5,1,0))
model_fit = model.fit(disp=0)
residuals = DataFrame(model_fit.resid)

# For Visualing how the Time Series looks like
residuals.plot()
pyplot.show()
residuals.plot(kind='kde')
pyplot.show()
print(residuals.describe())

# Creating dataframe   
dt = pd.DataFrame(index=range(0,len(df)),columns=['Date'])
dt=[]
for i in range(0,len(df)):
    dt.append(df.index[i])

series = df
X = series['Close'].values
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
dt_test=dt[size:len(X)]

history = [x for x in train]
predictions = list()
for t in range(len(test)):
    dt_prt = dt_test[t]
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    #print('predicted=%f, expected=%f' % (yhat, obs) +'     '+ str(dt_prt))

# Finding the error value
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)

#  For plotting the graph
pyplot.figure(figsize=(100,8))
pyplot.plot(test,color='blue',label='testing data')
pyplot.plot(predictions, color='red',label='predicted data')
pyplot.legend()
pyplot.show()

from sklearn import metrics
np.sqrt(metrics.mean_squared_error(test,predictions))

# %%
# Finding the error accuracy
from sklearn import metrics
rsme=np.sqrt(metrics.mean_squared_error(test,predictions))

print('accuracy  ::' + str(100-rsme))
# Out:
# accuracy  ::90.07444936569104

# %% [markdown]
# ## Seasonal ARIMA

# %%
import statsmodels.api as sm

# Fit the model
model =sm.tsa.statespace.SARIMAX(df['Close'], order=(5,1,0),seasonal_order=(1,1,1,12))
model_fit = model.fit(disp=0)
residuals = DataFrame(model_fit.resid)

# For Visualing how the Time Series looks like
residuals.plot()
pyplot.show()
residuals.plot(kind='kde')
pyplot.show()
print(residuals.describe())

# Creating dataframe   
dt = pd.DataFrame(index=range(0,len(df)),columns=['Date'])
dt=[]
for i in range(0,len(df)):
    dt.append(df.index[i])

series = df
X = series['Close'].values
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
dt_test=dt[size:len(X)]

history = [x for x in train]
predictions = list()
for t in range(len(test)):
    dt_prt = dt_test[t]
    model = sm.tsa.statespace.SARIMAX(history, order=(5,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    #print('predicted=%f, expected=%f' % (yhat, obs) +'     '+ str(dt_prt))

# Finding the error value
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)

#  For plotting the graph
pyplot.figure(figsize=(100,8))
pyplot.plot(test,color='blue',label='testing data')
pyplot.plot(predictions, color='red',label='predicted data')
pyplot.legend()
pyplot.show()

from sklearn import metrics
np.sqrt(metrics.mean_squared_error(test,predictions))
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                  0
# count  2464.000000
# mean      0.101659
# std      10.855371
# min    -156.915321
# 25%      -3.610085
# 50%      -0.002438
# 75%       4.134514
# max     311.205994
# Test MSE: 98.526
# 9.926034060520204

# %%
# Finding the error accuracy
from sklearn import metrics
rsme=np.sqrt(metrics.mean_squared_error(test,predictions))

print('accuracy  ::' + str(100-rsme))
# Out:
# accuracy  ::90.07396593947979

# %% [markdown]
# ## Conculsion
# * ARIMA yields better results in forecasting short term, whereas LSTM yields better results for long term modeling.
# * Machine learning problems with substantial dataset, its found that the average reduction in error rates obtained by LSTM is between 84–87 percent when compared to ARIMA indicating the superiority of LSTM to ARIMA.
# * Classical methods like ETS and ARIMA out-perform machine learning and deep learning methods for one-step forecasting on univariate datasets.
# * Classical methods like Theta and ARIMA out-perform machine learning and deep learning methods for multi-step forecasting on univariate datasets.
# * Classical methods like ARIMA focus on fixed temporal dependence: the relationship between observations at different times, which necessitates analysis and specification of the number of lag observations provided as input.
#
# <br>[for more information on the LSTM , ARIMA, AND seasonal ARIMA](https://mc.ai/arima-sarima-vs-lstm-with-ensemble-learning-insights-for-time-series-data/#:~:text=ARIMA%20yields%20better%20results%20in,results%20for%20long%20term%20modeling.&text=The%20number%20of%20training%20times,exhibits%20a%20truly%20random%20behavior.)
# <br>
# [Additional information](https://machinelearningmastery.com/findings-comparing-classical-and-machine-learning-methods-for-time-series-forecasting/)
